# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 5
#       3 import seaborn as sns
#       4 from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
# ----> 5 from tensorflow.keras.models import load_model
#       6 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       8 # ✅ Load Model & Weights
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:78
#      76 from tensorflow._api.v2 import queue
#      77 from tensorflow._api.v2 import ragged
# ---> 78 from tensorflow._api.v2 import random
#      79 from tensorflow._api.v2 import raw_ops
#      80 from tensorflow._api.v2 import saved_model
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\_api\v2\random\__init__.py:8
#       3 """Public API for tf._api.v2.random namespace
#       4 """
# ...
